# %%
import pandas as pd

# %%
columns = ['Timestamp', 'x accelerometer', 'y accelerometer', 
           
           'z accelerometer', 'x gyro', 'y gyro', 'z gyro', 'surface']

# %%
### Grass

grass_23_df = pd.read_csv('../datasets/combined/23_GSW_trimmed.csv', header = None)

grass_23_df.columns = columns

# %%
grass_24_df = pd.read_csv('../datasets/combined/24_GSW_trimmed.csv')

grass_24_df['surface'] = 'grass'

grass_24_df.columns = columns

# %%
grass_25_df = pd.read_csv('../datasets/combined/25_GSW_trimmed.csv')

# %%
grass_df = pd.concat([grass_23_df, grass_24_df, grass_25_df], axis = 0)

# %%
grass_df
# Out:
#                     Timestamp  x accelerometer  y accelerometer  \
# 0         2024-03-21 13:42:42        -0.028809        -0.299805
# 1         2024-03-21 13:42:42        -0.016357        -0.300293
# 2         2024-03-21 13:42:42        -0.023438        -0.287109
# 3         2024-03-21 13:42:42        -0.027832        -0.287354
# 4         2024-03-21 13:42:42         0.001465        -0.277832
# ...                       ...              ...              ...
# 5595  2024-03-21 13:52:12.126         0.015137        -0.169922
# 5596  2024-03-21 13:52:12.135         0.016357        -0.173096
# 5597  2024-03-21 13:52:12.145         0.027832        -0.173584
# 5598  2024-03-21 13:52:12.155         0.027344        -0.187988
# 5599  2024-03-21 13:52:12.165         0.025146        -0.194824
#
#       z accelerometer    x gyro    y gyro    z gyro surface
# 0           -0.958252  1.281738  1.068115  4.928589   grass
# 1           -0.949219  1.373291  0.991821  5.004883   grass
# ...

# %%
grass_df['surface'].unique()
# Out:
# array(['grass'], dtype=object)

# %%
grass_df.drop(['Timestamp'], axis = 1, inplace = True)

grass_df
# Out:
#       x accelerometer  y accelerometer  z accelerometer    x gyro    y gyro  \
# 0           -0.028809        -0.299805        -0.958252  1.281738  1.068115
# 1           -0.016357        -0.300293        -0.949219  1.373291  0.991821
# 2           -0.023438        -0.287109        -0.953125  1.068115  0.717163
# 3           -0.027832        -0.287354        -0.948730  0.839233  0.335693
# 4            0.001465        -0.277832        -0.946533  0.946045  0.183105
# ...               ...              ...              ...       ...       ...
# 5595         0.015137        -0.169922        -0.995117  2.227783 -1.846313
# 5596         0.016357        -0.173096        -0.998047  2.212524 -1.815796
# 5597         0.027832        -0.173584        -1.001709  2.090454 -1.647949
# 5598         0.027344        -0.187988        -1.001953  1.754761 -1.403808
# 5599         0.025146        -0.194824        -1.017822  1.464844 -1.205444
#
#         z gyro surface
# 0     4.928589   grass
# ...

# %%
grass_df.to_csv('../datasets/final/GSW.csv', index = False)

# %%
### Tile

tile_11_df = pd.read_csv('../datasets/combined/11_TS_trimmed.csv')

tile_11_df['surface'] = 'tile'

tile_11_df.columns = columns

# %%
tile_18_df = pd.read_csv('../datasets/combined/18_TS_trimmed.csv', header = None)

tile_18_df.columns = columns

# %%
tile_21_df = pd.read_csv('../datasets/combined/21_TS_trimmed.csv')

# %%
tile_df = pd.concat([tile_11_df, tile_18_df, tile_21_df], axis = 0)

# %%
tile_df
# Out:
#                     Timestamp  x accelerometer  y accelerometer  \
# 0     2024-03-20 09:35:12.340         0.092773        -0.054932
# 1     2024-03-20 09:35:12.350        -0.007324        -0.062012
# 2     2024-03-20 09:35:12.359        -0.054932        -0.028564
# 3     2024-03-20 09:35:12.369         0.028809        -0.003174
# 4     2024-03-20 09:35:12.380         0.077637        -0.110596
# ...                       ...              ...              ...
# 5195  2024-03-20 10:22:45.130         0.016602        -0.080322
# 5196  2024-03-20 10:22:45.139        -0.008789        -0.092773
# 5197  2024-03-20 10:22:45.150         0.013428        -0.066162
# 5198  2024-03-20 10:22:45.159        -0.018311        -0.072998
# 5199  2024-03-20 10:22:45.169        -0.002197        -0.045898
#
#       z accelerometer    x gyro    y gyro    z gyro surface
# 0           -0.982910  1.892090 -0.854492 -0.213623    tile
# 1           -1.098145 -0.061035  1.083374 -0.244141    tile
# ...

# %%
tile_df['surface'].unique()
# Out:
# array(['tile'], dtype=object)

# %%
tile_df.drop(['Timestamp'], axis = 1, inplace = True)

tile_df
# Out:
#       x accelerometer  y accelerometer  z accelerometer    x gyro    y gyro  \
# 0            0.092773        -0.054932        -0.982910  1.892090 -0.854492
# 1           -0.007324        -0.062012        -1.098145 -0.061035  1.083374
# 2           -0.054932        -0.028564        -0.941406  0.152588  0.045776
# 3            0.028809        -0.003174        -0.937012  1.632690 -0.900268
# 4            0.077637        -0.110596        -1.071045  1.983642  1.373291
# ...               ...              ...              ...       ...       ...
# 5195         0.016602        -0.080322        -0.970215  1.251221  0.396728
# 5196        -0.008789        -0.092773        -1.009033  1.617432  0.656128
# 5197         0.013428        -0.066162        -0.994141  1.907349  0.717163
# 5198        -0.018311        -0.072998        -1.035645  1.754761  0.686645
# 5199        -0.002197        -0.045898        -1.023193  1.922607  0.106812
#
#         z gyro surface
# 0    -0.213623    tile
# ...

# %%
tile_df.to_csv('../datasets/final/TS.csv', index = False)

# %%
### Asphalt

asphalt_15_df = pd.read_csv('../datasets/combined/15_AFW_trimmed.csv', header = None)

asphalt_15_df.columns = columns

# %%
asphalt_19_df = pd.read_csv('../datasets/combined/19_AFW_trimmed.csv')

# %%
asphalt_22_df = pd.read_csv('../datasets/combined/22_AFW_trimmed.csv')

asphalt_22_df['surface'] = 'asphalt'

asphalt_22_df.columns = columns

# %%
asphalt_df = pd.concat([asphalt_15_df, asphalt_19_df, asphalt_22_df], axis = 0)

# %%
asphalt_df
# Out:
#                     Timestamp  x accelerometer  y accelerometer  \
# 0          2024-03-20 9:54:37        -0.087402         0.024414
# 1          2024-03-20 9:54:37        -0.162354         0.053223
# 2          2024-03-20 9:54:37        -0.010254         0.014160
# 3          2024-03-20 9:54:37         0.208252         0.027588
# 4          2024-03-20 9:54:37        -0.027832        -0.030029
# ...                       ...              ...              ...
# 4866  2024-03-20 10:28:31.889         0.010986        -0.072021
# 4867  2024-03-20 10:28:31.899         0.010498        -0.071289
# 4868  2024-03-20 10:28:31.909         0.008057        -0.069824
# 4869  2024-03-20 10:28:31.920         0.007813        -0.068604
# 4870  2024-03-20 10:28:31.930         0.008545        -0.070557
#
#       z accelerometer    x gyro    y gyro    z gyro  surface
# 0           -0.899170 -1.220703 -0.686645 -0.961304  asphalt
# 1           -0.816895 -1.525879 -1.281738  0.488281  asphalt
# ...

# %%
asphalt_df['surface'].unique()
# Out:
# array(['asphalt'], dtype=object)

# %%
asphalt_df.drop(['Timestamp'], axis = 1, inplace = True)

asphalt_df
# Out:
#       x accelerometer  y accelerometer  z accelerometer    x gyro    y gyro  \
# 0           -0.087402         0.024414        -0.899170 -1.220703 -0.686645
# 1           -0.162354         0.053223        -0.816895 -1.525879 -1.281738
# 2           -0.010254         0.014160        -1.160156  0.717163 -0.503540
# 3            0.208252         0.027588        -1.086426 -0.473022  0.625610
# 4           -0.027832        -0.030029        -0.930908 -3.982544  2.029419
# ...               ...              ...              ...       ...       ...
# 4866         0.010986        -0.072021        -1.009033  0.671387  0.228882
# 4867         0.010498        -0.071289        -1.008301  0.671387  0.213623
# 4868         0.008057        -0.069824        -1.006836  0.656128  0.152588
# 4869         0.007813        -0.068604        -1.007813  0.686645  0.228882
# 4870         0.008545        -0.070557        -1.005859  0.701904  0.228882
#
#         z gyro  surface
# 0    -0.961304  asphalt
# ...

# %%
asphalt_df.to_csv('../datasets/final/AFW.csv', index = False)

# %%
### Concrete

concrete_13_df = pd.read_csv('../datasets/combined/13_CFD_trimmed.csv')

# %%
concrete_17_df = pd.read_csv('../datasets/combined/17_CFD_trimmed.csv')

concrete_17_df['surface'] = 'concrete'

concrete_17_df.columns = columns

# %%
concrete_20_df = pd.read_csv('../datasets/combined/20_CFD_trimmed.csv', header = None)

concrete_20_df.columns = columns

# %%
concrete_df = pd.concat([concrete_13_df, concrete_17_df, concrete_20_df], axis = 0)

# %%
concrete_df
# Out:
#                     Timestamp  x accelerometer  y accelerometer  \
# 0     2024-03-20 09:42:57.299        -0.072754        -0.024170
# 1     2024-03-20 09:42:57.310        -0.065186        -0.037354
# 2     2024-03-20 09:42:57.319        -0.029785        -0.037354
# 3     2024-03-20 09:42:57.330        -0.001221        -0.033203
# 4     2024-03-20 09:42:57.340         0.037842        -0.018066
# ...                       ...              ...              ...
# 5105      2024-03-20 10:18:32         0.130615        -0.036621
# 5106      2024-03-20 10:18:32         0.036865        -0.011963
# 5107      2024-03-20 10:18:32        -0.125977        -0.032959
# 5108      2024-03-20 10:18:32        -0.026855        -0.000244
# 5109      2024-03-20 10:18:32         0.118652        -0.044189
#
#       z accelerometer    x gyro    y gyro    z gyro   surface
# 0           -1.005615  0.595093  0.823975  0.595093  concrete
# 1           -1.033447  1.403808  0.747681  0.350952  concrete
# ...

# %%
concrete_df['surface'].unique()
# Out:
# array(['concrete'], dtype=object)

# %%
concrete_df.drop(['Timestamp'], axis = 1, inplace = True)

concrete_df
# Out:
#       x accelerometer  y accelerometer  z accelerometer    x gyro    y gyro  \
# 0           -0.072754        -0.024170        -1.005615  0.595093  0.823975
# 1           -0.065186        -0.037354        -1.033447  1.403808  0.747681
# 2           -0.029785        -0.037354        -1.014160  1.296997  0.152588
# 3           -0.001221        -0.033203        -1.005859  0.961304  0.015259
# 4            0.037842        -0.018066        -1.007813  1.266479  0.564575
# ...               ...              ...              ...       ...       ...
# 5105         0.130615        -0.036621        -1.022705  3.219604  1.480102
# 5106         0.036865        -0.011963        -1.070557  0.595093  2.807617
# 5107        -0.125977        -0.032959        -0.997559 -0.015259  2.105713
# 5108        -0.026855        -0.000244        -0.992676  0.854492 -0.473022
# 5109         0.118652        -0.044189        -0.999512  1.403808  0.015259
#
#         z gyro   surface
# 0     0.595093  concrete
# ...

# %%
concrete_df.to_csv('../datasets/final/CFD.csv', index = False)

# %%
### Stones

stone_12_df = pd.read_csv('../datasets/combined/12_SCW_trimmed.csv', header = None)

stone_12_df.columns = columns

# %%
stone_14_df = pd.read_csv('../datasets/combined/14_SCW_trimmed.csv')

stone_14_df['surface'] = 'stones'

stone_14_df.columns = columns

# %%
stone_16_df = pd.read_csv('../datasets/combined/16_SCW_trimmed.csv')

# %%
stone_df = pd.concat([stone_12_df, stone_14_df, stone_16_df], axis = 0)

# %%
stone_df
# Out:
#                     Timestamp  x accelerometer  y accelerometer  \
# 0          2024-03-20 9:38:45        -0.179688        -0.122314
# 1          2024-03-20 9:38:45        -0.166748        -0.115967
# 2          2024-03-20 9:38:45        -0.086426        -0.140137
# 3          2024-03-20 9:38:45        -0.086426        -0.134277
# 4          2024-03-20 9:38:45         0.006592        -0.101563
# ...                       ...              ...              ...
# 4695  2024-03-20 10:00:23.149        -0.275391        -0.194580
# 4696  2024-03-20 10:00:23.159        -0.298828        -0.199463
# 4697  2024-03-20 10:00:23.170        -0.181641        -0.164063
# 4698  2024-03-20 10:00:23.180        -0.191162        -0.209961
# 4699  2024-03-20 10:00:23.190        -0.259033        -0.280273
#
#       z accelerometer     x gyro    y gyro    z gyro surface
# 0           -0.964600  -2.655029  1.342773  2.456665  stones
# 1           -0.987305  -3.677368 -0.045776  4.333496  stones
# ...

# %%
stone_df['surface'].unique()
# Out:
# array(['stones'], dtype=object)

# %%
stone_df.drop(['Timestamp'], axis = 1, inplace = True)

stone_df
# Out:
#       x accelerometer  y accelerometer  z accelerometer     x gyro    y gyro  \
# 0           -0.179688        -0.122314        -0.964600  -2.655029  1.342773
# 1           -0.166748        -0.115967        -0.987305  -3.677368 -0.045776
# 2           -0.086426        -0.140137        -1.041260  -1.312256  0.152588
# 3           -0.086426        -0.134277        -0.964600  -1.586914  0.122070
# 4            0.006592        -0.101563        -0.971924  -2.059937 -1.266479
# ...               ...              ...              ...        ...       ...
# 4695        -0.275391        -0.194580        -0.808838 -10.696410  6.469726
# 4696        -0.298828        -0.199463        -0.806396  -9.216309  5.065917
# 4697        -0.181641        -0.164063        -0.912842  -7.690429  2.929687
# 4698        -0.191162        -0.209961        -1.000488  -2.578735  2.624511
# 4699        -0.259033        -0.280273        -1.057617  -0.686645  2.456665
#
#         z gyro surface
# ...

# %%
stone_df.to_csv('../datasets/final/SCW.csv', index = False)
