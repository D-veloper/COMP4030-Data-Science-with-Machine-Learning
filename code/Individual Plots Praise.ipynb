# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
columns = ['Timestamp', 'x accelerometer', 'y accelerometer', 
           
           'z accelerometer', 'x gyro', 'y gyro', 'z gyro']

# %%
p_grass_df = pd.read_csv('../datasets/praise/23_grass_slopy_wet.csv', header = None)
b_grass_df = pd.read_csv('../datasets/bushra/24_grass_slopy_wet.csv', header = None)
d_grass_df = pd.read_csv('../datasets/dayo/25_grass_slopy_wet.csv', header = None)

p_concrete_df = pd.read_csv('../datasets/praise/20_concrete_dry_flat.csv', header = None)
b_concrete_df = pd.read_csv('../datasets/bushra/17_concrete_dry_flat.csv', header = None)
d_concrete_df = pd.read_csv('../datasets/dayo/13_concrete_dry_flat.csv', header = None)

p_asphalt_df = pd.read_csv('../datasets/praise/15_asphalt_flat_wet.csv', header = None)
b_asphalt_df = pd.read_csv('../datasets/bushra/22_asphalt_flat_wet.csv', header = None)
d_asphalt_df = pd.read_csv('../datasets/dayo/19_asphalt_flat_wet.csv', header = None)

p_stones_df = pd.read_csv('../datasets/praise/12_stones_coarse_wet.csv', header = None)
b_stones_df = pd.read_csv('../datasets/bushra/14_stones_coarse_wet.csv', header = None)
d_stones_df = pd.read_csv('../datasets/dayo/16_stones_coarse_wet.csv', header = None)

p_tile_df = pd.read_csv('../datasets/praise/tile.csv', header = None)
b_tile_df = pd.read_csv('../datasets/bushra/11_tile_smooth.csv', header = None)
d_tile_df = pd.read_csv('../datasets/dayo/21_tile_smooth.csv', header = None)

# %%
all_data_frames = [p_grass_df, p_concrete_df, p_asphalt_df, p_stones_df, p_tile_df, b_grass_df, b_concrete_df, b_asphalt_df, b_stones_df, b_tile_df, d_grass_df, d_concrete_df, d_asphalt_df, d_stones_df, d_tile_df]
for df in all_data_frames:
    df.columns = columns

# %%
# for i, feature in enumerate(grass_df.columns[1: ], 0):
    
#     print(i, feature)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[5], line 1
# ----> 1 for i, feature in enumerate(grass_df.columns[1: ], 0):
#       3     print(i, feature)
#
# NameError: name 'grass_df' is not defined

# %%
fig, ax = plt.subplots(6, 3, figsize=(13, 30), gridspec_kw={'hspace': 0.4})

for i, feature in enumerate(p_grass_df.columns[1:], 0):
    
    ax[i, 0].plot(p_grass_df[-2900:][feature], color = 'green')
    
    ax[i, 0].set_title('Praise '+ feature)
    
    ax[i, 0].set_xlabel('Sample Number')
    
    ax[i, 0].set_ylabel(feature)
    
    if len(feature) > 6:
         ax[i, 0].set_ylim(-1, 1) if feature[0] == 'x' else ax[i, 0].set_ylim(-0.8, 0.6) if feature[0] == 'y' else ax[i, 0].set_ylim(-2.25, 0)
    else:
         ax[i, 0].set_ylim(-30, 22) if feature[0] == 'x' else ax[i, 0].set_ylim(-15, 15) if feature[0] == 'y' else ax[i, 0].set_ylim(-15, 15)
    

# for i, feature in enumerate(b_grass_df.columns[1:], 0):
    
#     ax[i, 1].plot(b_grass_df[3500:4500][feature], color = 'green')
    
#     ax[i, 1].set_title('Bushra '+ feature)
    
#     ax[i, 1].set_xlabel('Sample Number')
    
#     # ax[i, 1].set_ylabel(feature)
    
#     if len(feature) > 6:
#          ax[i, 1].set_ylim(-1, 1) if feature[0] == 'x' else ax[i, 1].set_ylim(-0.8, 0.6) if feature[0] == 'y' else ax[i, 1].set_ylim(-2.25, 0)
#     else:
#          ax[i, 1].set_ylim(-30, 22) if feature[0] == 'x' else ax[i, 1].set_ylim(-15, 15) if feature[0] == 'y' else ax[i, 1].set_ylim(-15, 15)

# for i, feature in enumerate(d_grass_df.columns[1:], 0):
    
#     ax[i, 2].plot(d_grass_df[3500:4500][feature], color = 'green')
    
#     ax[i, 2].set_title('Dayo '+ feature)
    
#     ax[i, 2].set_xlabel('Sample Number')
    
#     # ax[i, 2].set_ylabel(feature)
    
#     if len(feature) > 6:
#          ax[i, 2].set_ylim(-1, 1) if feature[0] == 'x' else ax[i, 2].set_ylim(-0.8, 0.6) if feature[0] == 'y' else ax[i, 2].set_ylim(-2.25, 0)
#     else:
#          ax[i, 2].set_ylim(-30, 22) if feature[0] == 'x' else ax[i, 2].set_ylim(-15, 15) if feature[0] == 'y' else ax[i, 2].set_ylim(-15, 15)

plt.show()

# %%
fig, ax = plt.subplots(6, 3, figsize=(13, 30), gridspec_kw={'hspace': 0.4})

for i, feature in enumerate(p_concrete_df.columns[1:], 0):
    
    ax[i, 0].plot(p_concrete_df[-2600:][feature], color = 'grey')
    
    ax[i, 0].set_title('Praise '+ feature)
    
    ax[i, 0].set_xlabel('Sample Number')
    
    ax[i, 0].set_ylabel(feature)
    
    if len(feature) > 6:
         ax[i, 0].set_ylim(-1, 1) if feature[0] == 'x' else ax[i, 0].set_ylim(-0.8, 0.6) if feature[0] == 'y' else ax[i, 0].set_ylim(-2.25, 0)
    else:
         ax[i, 0].set_ylim(-30, 22) if feature[0] == 'x' else ax[i, 0].set_ylim(-15, 15) if feature[0] == 'y' else ax[i, 0].set_ylim(-15, 15)
    

# for i, feature in enumerate(b_concrete_df.columns[1:], 0):
    
#     ax[i, 1].plot(b_concrete_df[3500:4500][feature], color = 'grey')
    
#     ax[i, 1].set_title('Bushra '+ feature)
    
#     ax[i, 1].set_xlabel('Sample Number')
    
#     # ax[i, 1].set_ylabel(feature)
    
#     if len(feature) > 6:
#          ax[i, 1].set_ylim(-1, 1) if feature[0] == 'x' else ax[i, 1].set_ylim(-0.8, 0.6) if feature[0] == 'y' else ax[i, 1].set_ylim(-2.25, 0)
#     else:
#          ax[i, 1].set_ylim(-30, 22) if feature[0] == 'x' else ax[i, 1].set_ylim(-15, 15) if feature[0] == 'y' else ax[i, 1].set_ylim(-15, 15)

            
# for i, feature in enumerate(d_concrete_df.columns[1:], 0):
    
#     ax[i, 2].plot(d_concrete_df[3500:4500][feature], color = 'grey')
    
#     ax[i, 2].set_title('Dayo '+ feature)
    
#     ax[i, 2].set_xlabel('Sample Number')
    
#     # ax[i, 2].set_ylabel(feature)
    
#     if len(feature) > 6:
#          ax[i, 2].set_ylim(-1, 1) if feature[0] == 'x' else ax[i, 2].set_ylim(-0.8, 0.6) if feature[0] == 'y' else ax[i, 2].set_ylim(-2.25, 0)
#     else:
#          ax[i, 2].set_ylim(-30, 22) if feature[0] == 'x' else ax[i, 2].set_ylim(-15, 15) if feature[0] == 'y' else ax[i, 2].set_ylim(-15, 15)

plt.show()

# %%
fig, ax = plt.subplots(6, 3, figsize=(13, 30), gridspec_kw={'hspace': 0.4})

for i, feature in enumerate(p_asphalt_df.columns[1:], 0):
    
    ax[i, 0].plot(p_asphalt_df[-3000:][feature], color = 'black')
    
    ax[i, 0].set_title('Praise '+ feature)
    
    ax[i, 0].set_xlabel('Sample Number')
    
    ax[i, 0].set_ylabel(feature)
    
    if len(feature) > 6:
         ax[i, 0].set_ylim(-1, 1) if feature[0] == 'x' else ax[i, 0].set_ylim(-0.8, 0.6) if feature[0] == 'y' else ax[i, 0].set_ylim(-2.25, 0)
    else:
         ax[i, 0].set_ylim(-30, 22) if feature[0] == 'x' else ax[i, 0].set_ylim(-15, 15) if feature[0] == 'y' else ax[i, 0].set_ylim(-15, 15)
    

# for i, feature in enumerate(b_asphalt_df.columns[1:], 0):
    
#     ax[i, 1].plot(b_asphalt_df[3500:4500][feature], color = 'black')
    
#     ax[i, 1].set_title('Bushra '+ feature)
    
#     ax[i, 1].set_xlabel('Sample Number')
    
#     # ax[i, 1].set_ylabel(feature)
    
#     if len(feature) > 6:
#          ax[i, 1].set_ylim(-1, 1) if feature[0] == 'x' else ax[i, 1].set_ylim(-0.8, 0.6) if feature[0] == 'y' else ax[i, 1].set_ylim(-2.25, 0)
#     else:
#          ax[i, 1].set_ylim(-30, 22) if feature[0] == 'x' else ax[i, 1].set_ylim(-15, 15) if feature[0] == 'y' else ax[i, 1].set_ylim(-15, 15)

# for i, feature in enumerate(d_asphalt_df.columns[1:], 0):
    
#     ax[i, 2].plot(d_asphalt_df[3500:4500][feature], color = 'black')
    
#     ax[i, 2].set_title('Dayo '+ feature)
    
#     ax[i, 2].set_xlabel('Sample Number')
    
#     # ax[i, 2].set_ylabel(feature)
    
#     if len(feature) > 6:
#         ax[i, 2].set_ylim(-1, 1) if feature[0] == 'x' else ax[i, 2].set_ylim(-1.5, 0.6) if feature[0] == 'y' else ax[i, 2].set_ylim(-2.5, 0.3)
#     else:
#         ax[i, 2].set_ylim(-45, 42) if feature[0] == 'x' else ax[i, 2].set_ylim(-35, 33) if feature[0] == 'y' else ax[i, 2].set_ylim(-25, 33)

plt.show()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[59], line 7
#       3 for i, feature in enumerate(p_asphalt_df.columns[1:], 0):
#       5     ax[i, 0].plot(p_asphalt_df[-3000:][feature], color = 'black')
# ----> 7     ax[i, 0].set_title('Praise '+ feature)
#       9     ax[i, 0].set_xlabel('Sample Number')
#      11     ax[i, 0].set_ylabel(feature)
#
# TypeError: can only concatenate str (not "int") to str

# %%
fig, ax = plt.subplots(6, 3, figsize=(13, 30), gridspec_kw={'hspace': 0.4})

for i, feature in enumerate(p_tile_df.columns[1:], 0):
    
    ax[i, 0].plot(p_tile_df[feature], color = 'wheat')
    
    ax[i, 0].set_title('Praise '+ feature)
    
    ax[i, 0].set_xlabel('Sample Number')
    
    ax[i, 0].set_ylabel(feature)
    
    if len(feature) > 6:
         ax[i, 0].set_ylim(-1, 1) if feature[0] == 'x' else ax[i, 0].set_ylim(-0.8, 0.6) if feature[0] == 'y' else ax[i, 0].set_ylim(-2.25, 0)
    else:
         ax[i, 0].set_ylim(-30, 22) if feature[0] == 'x' else ax[i, 0].set_ylim(-15, 15) if feature[0] == 'y' else ax[i, 0].set_ylim(-15, 15)
    

# for i, feature in enumerate(b_tile_df.columns[1:], 0):
    
#     ax[i, 1].plot(b_tile_df[3500:4500][feature], color = 'wheat')
    
#     ax[i, 1].set_title('Bushra '+ feature)
    
#     ax[i, 1].set_xlabel('Sample Number')
    
#     # ax[i, 1].set_ylabel(feature)
    
#     if len(feature) > 6:
#          ax[i, 1].set_ylim(-1, 1) if feature[0] == 'x' else ax[i, 1].set_ylim(-0.8, 0.6) if feature[0] == 'y' else ax[i, 1].set_ylim(-2.25, 0)
#     else:
#          ax[i, 1].set_ylim(-30, 22) if feature[0] == 'x' else ax[i, 1].set_ylim(-15, 15) if feature[0] == 'y' else ax[i, 1].set_ylim(-15, 15)

# for i, feature in enumerate(d_tile_df.columns[1:], 0):
    
#     ax[i, 2].plot(d_tile_df[3500:4500][feature], color = 'wheat')
    
#     ax[i, 2].set_title('Dayo '+ feature)
    
#     ax[i, 2].set_xlabel('Sample Number')
    
#     # ax[i, 2].set_ylabel(feature)
    
#     if len(feature) > 6:
#         ax[i, 2].set_ylim(-1, 1) if feature[0] == 'x' else ax[i, 2].set_ylim(-1.5, 0.6) if feature[0] == 'y' else ax[i, 2].set_ylim(-2.5, 0.3)
#     else:
#         ax[i, 2].set_ylim(-45, 42) if feature[0] == 'x' else ax[i, 2].set_ylim(-35, 33) if feature[0] == 'y' else ax[i, 2].set_ylim(-25, 33)

plt.show()

# %%
fig, ax = plt.subplots(6, 3, figsize=(13, 30), gridspec_kw={'hspace': 0.4})

for i, feature in enumerate(p_stones_df.columns[1:], 0):
    
    ax[i, 0].plot(p_stones_df[-2000:][feature], color = 'saddlebrown')
    
    ax[i, 0].set_title('Praise '+ feature)
    
    ax[i, 0].set_xlabel('Sample Number')
    
    ax[i, 0].set_ylabel(feature)
    
    if len(feature) > 6:
         ax[i, 0].set_ylim(-1, 1) if feature[0] == 'x' else ax[i, 0].set_ylim(-0.8, 0.6) if feature[0] == 'y' else ax[i, 0].set_ylim(-2.25, 0)
    else:
         ax[i, 0].set_ylim(-30, 22) if feature[0] == 'x' else ax[i, 0].set_ylim(-15, 15) if feature[0] == 'y' else ax[i, 0].set_ylim(-15, 15)
    

# for i, feature in enumerate(b_stones_df.columns[1:], 0):
    
#     ax[i, 1].plot(b_stones_df[3500:4500][feature], color = 'saddlebrown')
    
#     ax[i, 1].set_title('Bushra '+ feature)
    
#     ax[i, 1].set_xlabel('Sample Number')
    
#     # ax[i, 1].set_ylabel(feature)
    
#     if len(feature) > 6:
#          ax[i, 1].set_ylim(-1, 1) if feature[0] == 'x' else ax[i, 1].set_ylim(-0.8, 0.6) if feature[0] == 'y' else ax[i, 1].set_ylim(-2.25, 0)
#     else:
#          ax[i, 1].set_ylim(-30, 22) if feature[0] == 'x' else ax[i, 1].set_ylim(-15, 15) if feature[0] == 'y' else ax[i, 1].set_ylim(-15, 15)

# for i, feature in enumerate(d_stones_df.columns[1:], 0):
    
#     ax[i, 2].plot(d_stones_df[3500:4500][feature], color = 'saddlebrown')
    
#     ax[i, 2].set_title('Dayo '+ feature)
    
#     ax[i, 2].set_xlabel('Sample Number')
    
#     # ax[i, 2].set_ylabel(feature)
    
#     if len(feature) > 6:
#         ax[i, 2].set_ylim(-1, 1) if feature[0] == 'x' else ax[i, 2].set_ylim(-1.5, 0.6) if feature[0] == 'y' else ax[i, 2].set_ylim(-2.5, 0.3)
#     else:
#         ax[i, 2].set_ylim(-45, 42) if feature[0] == 'x' else ax[i, 2].set_ylim(-35, 33) if feature[0] == 'y' else ax[i, 2].set_ylim(-25, 33)

plt.show()

# %%
fig, ax = plt.subplots(6, 1, figsize=(13, 30), gridspec_kw={'hspace': 0.4})

features_to_plot = grass_df.columns[1:]

for i, feature in enumerate(features_to_plot, 0):
    
    data_to_plot = pd.DataFrame({'Concrete': concrete_df[feature], 'Grass': grass_df[feature],
                                 
                                 'Asphalt': asphalt_df[feature]})
    
    sns.boxplot(data = data_to_plot, ax = ax[i])
    
    ax[i].set_xticks([0, 1, 2])
    
    ax[i].set_xticklabels(['Concrete', 'Grass', 'Asphalt'])
    
    ax[i].set_title(f'Box Plot of {feature}')
